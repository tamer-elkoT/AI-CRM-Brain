# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales = pd.read_csv("/mnt/d/01_Projects/NLP/AI CRM Brain/AI-CRM-Brain/data/preprocessed/WA_Fn-UseC_-Sales-Win-Loss.csv")
sales.head()
# Out:
#    Opportunity Number     Supplies Subgroup          Supplies Group  \
# 0             1641984  Exterior Accessories         Car Accessories
# 1             1658010  Exterior Accessories         Car Accessories
# 2             1674737      Motorcycle Parts  Performance & Non-auto
# 3             1675224         Shelters & RV  Performance & Non-auto
# 4             1689785  Exterior Accessories         Car Accessories
#
#       Region Route To Market  Elapsed Days In Sales Stage Opportunity Result  \
# 0  Northwest    Fields Sales                           76                Won
# 1    Pacific        Reseller                           63               Loss
# 2    Pacific        Reseller                           24                Won
# 3    Midwest        Reseller                           16               Loss
# 4    Pacific        Reseller                           69               Loss
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# ...

# %%
sales["Opportunity Result"].value_counts()
# Out:
# Opportunity Result
# Loss    60398
# Won     17627
# Name: count, dtype: int64

# %%
fake = pd.read_csv("/mnt/d/01_Projects/NLP/AI CRM Brain/AI-CRM-Brain/test_deals.csv")
fake.head()
# Out:
#                Deal_ID                  Deal_Name  Amount  Expected_Revenue  \
# 0  7396871000000719033                 cairo deal   80000             32000
# 1  7396871000000719002                    Mansura   10000              5000
# 2  7396871000000612198                       King   60000                 0
# 3  7396871000000612197  Truhlar And Truhlar Attys   45000                 0
# 4  7396871000000612196           Commercial Press   45000                 0
#
#    Probability                Stage Closing_Date  \
# 0           40    Value Proposition   2026-08-12
# 1           50           Closed Won   2026-06-13
# 2           60  Id. Decision Makers   2026-05-08
# 3           20       Needs Analysis   2026-05-06
# 4            0          Closed Lost   2026-05-07
#
#                       Account_Name             Contact_Name   Owner_Name
# 0                              SEG            Mohamed Elkot  Tamer Elkot
# ...

# %%
fake.columns
# Out:
# Index(['Deal_ID', 'Deal_Name', 'Amount', 'Expected_Revenue', 'Probability',
#        'Stage', 'Closing_Date', 'Account_Name', 'Contact_Name', 'Owner_Name'],
#       dtype='object')

# %%
maven_df = pd.read_csv("/mnt/d/01_Projects/NLP/AI CRM Brain/AI-CRM-Brain/data/raw data/sales_pipeline.csv")
maven_df.head()
# Out:
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        Won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        Won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        Won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        Won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        Won
#
#   engage_date close_date  close_value
# 0  10/20/2016   3/1/2017       1054.0
# 1  10/25/2016  3/11/2017       4514.0
# 2  10/25/2016   3/7/2017         50.0
# 3  10/25/2016   3/9/2017        588.0
# 4  10/25/2016   3/2/2017        517.0

# %%
columns_to_keep = [
    'opportunity_id', 'sales_agent', 'account', 
    'deal_stage', 'close_value', 'close_date'
]

df = maven_df[columns_to_keep]
df.head()
# Out:
#   opportunity_id      sales_agent  account deal_stage  close_value close_date
# 0       1C1I7A6R      Moses Frase  Cancity        Won       1054.0   3/1/2017
# 1       Z063OYW0  Darcel Schlecht    Isdom        Won       4514.0  3/11/2017
# 2       EC4QE1BX  Darcel Schlecht  Cancity        Won         50.0   3/7/2017
# 3       MV1LWRNH      Moses Frase  Codehow        Won        588.0   3/9/2017
# 4       PE84CX4O        Zane Levy   Hatfan        Won        517.0   3/2/2017

# %%
df = df.rename(columns={
    'opportunity_id': 'Deal_ID',
    'sales_agent': 'Owner_Name',
    'account': 'Account_Name',
    'deal_stage': 'Stage',
    'close_value': 'Amount',
    'close_date': 'Closing_Date'
})

# %%
df.head()
# Out:
#     Deal_ID       Owner_Name Account_Name Stage  Amount Closing_Date
# 0  1C1I7A6R      Moses Frase      Cancity   Won  1054.0     3/1/2017
# 1  Z063OYW0  Darcel Schlecht        Isdom   Won  4514.0    3/11/2017
# 2  EC4QE1BX  Darcel Schlecht      Cancity   Won    50.0     3/7/2017
# 3  MV1LWRNH      Moses Frase      Codehow   Won   588.0     3/9/2017
# 4  PE84CX4O        Zane Levy       Hatfan   Won   517.0     3/2/2017

# %%
df["Stage"].value_counts()
# Out:
# Stage
# Won            4238
# Lost           2473
# Engaging       1589
# Prospecting     500
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#              Amount
# count   6711.000000
# mean    1490.915512
# std     2320.670773
# min        0.000000
# 25%        0.000000
# 50%      472.000000
# 75%     3225.000000
# max    30288.000000

# %%
df.columns
# Out:
# Index(['Deal_ID', 'Owner_Name', 'Account_Name', 'Stage', 'Amount',
#        'Closing_Date'],
#       dtype='object')

# %%
df.shape
# Out:
# (8800, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8800 entries, 0 to 8799
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Deal_ID       8800 non-null   object
#  1   Owner_Name    8800 non-null   object
#  2   Account_Name  7375 non-null   object
#  3   Stage         8800 non-null   object
#  4   Amount        6711 non-null   float64
#  5   Closing_Date  6711 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 412.6+ KB
