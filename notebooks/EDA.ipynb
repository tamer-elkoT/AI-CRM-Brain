# %%
import pandas as pd

# %%
df = pd.read_csv("/mnt/d/01_Projects/NLP/AI CRM Brain/AI-CRM-Brain/test_deals.csv")
df.head()
# Out:
#                Deal_ID                  Deal_Name  Amount  Expected_Revenue  \
# 0  7396871000000612198                       King   60000                 0
# 1  7396871000000612197  Truhlar And Truhlar Attys   45000                 0
# 2  7396871000000612196           Commercial Press   45000                 0
# 3  7396871000000612195         Morlong Associates   35000                 0
# 4  7396871000000612194                    Chapman   70000                 0
#
#    Probability                Stage Closing_Date  \
# 0           60  Id. Decision Makers   2026-05-08
# 1           20       Needs Analysis   2026-05-06
# 2            0          Closed Lost   2026-05-07
# 3          100           Closed Won   2026-05-08
# 4           90   Negotiation/Review   2026-05-06
#
#                    Account_Name             Contact_Name   Owner_Name
# 0                 King (Sample)    Kris Marrier (Sample)  Tamer Elkot
# 1  Truhlar And Truhlar (Sample)     Sage Wieser (Sample)  Tamer Elkot
# ...
